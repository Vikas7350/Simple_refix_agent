# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikas7350/Simple_refix_agent/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Vikas Bhawarlal Choudhari
#
#
# PRN : 202401040012
#
#
# Roll No 02
#
# Batch : A1
#
# Division : A

# %% [markdown]
# # Smart Autonomous Vacuum Cleaning Agent for MITAOE Library
#
# ---
#
# ## Title
#
# ### Smart Autonomous Vacuum Cleaning Agent for MITAOE Library
#
# The project implements a battery-aware Simple Reflex Vacuum Cleaner Agent using Python. The agent operates in different areas of the MITAOE library, detects whether an area is clean or dirty, performs cleaning when required, moves between library areas, monitors its battery level, and calculates its performance score.
#
# ---
#
# # Aim
#
# To design and implement a Smart Autonomous Vacuum Cleaning Agent using Python for the MITAOE Library that can detect dirty areas, clean them, move between different library sections, monitor its battery level, recharge when necessary, and evaluate its performance using a scoring mechanism.
#
# ---
#
# # Experiment Objectives
#
# To design functionality for a vacuum cleaner agent that:
#
# 1. Detects clean and dirty areas in the MITAOE Library.
# 2. Automatically cleans an area when it is dirty.
# 3. Moves between different areas of the library.
# 4. Maintains a performance score based on its actions.
# 5. Monitors the battery level of the vacuum cleaner.
# 6. Moves to a predefined charging station when the battery becomes low.
# 7. Recharges the battery and continues the cleaning process.
# 8. Demonstrates the working of a Simple Reflex Agent in a real-world environment.
#
# ---
#
# # Theory
#
# An **Artificial Intelligence Agent** is a system that perceives its environment and performs actions to achieve a specific goal.
#
# A **Simple Reflex Agent** selects an action based only on the current percept or current condition of the environment. It uses predefined **condition-action rules** and does not require information about previous states.
#
# In this experiment, the environment represents different areas of the MITAOE Library.
#
# The library consists of the following areas:
#
# - Reading Hall
# - Book Section
# - Reception
# - Cabin 1
# - Cabin 2
#
# Each area has one of two possible conditions:
#
# - **0 represents a Clean area**
# - **1 represents a Dirty area**
#
# The initial condition of each area is generated randomly using Python's `random` module.
#
# The vacuum cleaner senses the current condition of an area and performs an action according to predefined rules.
#
# ### Condition-Action Rules
#
# **Rule 1:** If the current area is dirty, clean the area.
#
# **Rule 2:** If the current area is clean, no cleaning action is required.
#
# **Rule 3:** If more areas are remaining, move to the next area.
#
# **Rule 4:** If the battery level becomes less than or equal to 20%, move to the charging station.
#
# **Rule 5:** After charging, restore the battery level to 100% and continue the cleaning process.
#
# The performance of the agent is measured using rewards and penalties.
#
# | Action | Performance |
# |---|---:|
# | Cleaning a dirty area | +1 |
# | Moving to the next area | -1 |
# | No action in a clean area | 0 |
#
# The battery is also reduced when the vacuum performs cleaning or movement operations.
#
# Thus, the agent attempts to clean all the library areas while monitoring its battery and maintaining a performance score.
#
# ---
#
# # PEAS Description
#
# | Component | Description |
# |---|---|
# | **P – Performance Measure** | Number of areas cleaned, performance score, battery level, and efficient movement |
# | **E – Environment** | MITAOE Library containing Reading Hall, Book Section, Reception, Cabin 1, Cabin 2, and Charging Station |
# | **A – Actuators** | Movement mechanism, cleaning mechanism, and charging mechanism |
# | **S – Sensors** | Dirt/cleanliness sensor, location sensor, and battery-level sensor |
#
# ---
#
# # Flowchart
#
#
# ```text
#                               ┌───────────────────┐
#                               │       START       │
#                               └─────────┬─────────┘
#                                         │
#                                         ▼
#                     ┌───────────────────────────────────┐
#                     │ Create Environment Object         │
#                     │ environment = Environment()       │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Create Library Areas               │
#                     │ • Reading Hall                     │
#                     │ • Book Section                     │
#                     │ • Reception                        │
#                     │ • Cabin 1                          │
#                     │ • Cabin 2                          │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Assign Random Status to Each Area  │
#                     │                                    │
#                     │ random.randint(0, 1)               │
#                     │                                    │
#                     │ 0 = Clean                          │
#                     │ 1 = Dirty                          │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Display Initial Library Condition │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Create Reflex Agent Object         │
#                     │ agent = ReflexAgent(environment)  │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Initialize Agent                   │
#                     │                                    │
#                     │ Location = Reading Hall            │
#                     │ Score = 0                          │
#                     │ Battery = 100%                     │
#                     │ Cleaned Rooms = 0                  │
#                     │ Charging Station = Reception       │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Start Cleaning Process            │
#                     │ Call agent.act()                  │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                     ┌───────────────────────────────────┐
#                     │ Select Current Library Area        │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                               ┌───────────────────┐
#                               │ Battery <= 20% ?  │
#                               └───────┬─────┬─────┘
#                                       │Yes  │No
#                                       ▼     │
#                     ┌───────────────────────────────┐    │
#                     │ Move to Charging Station      │    │
#                     │ Location = Reception          │    │
#                     └───────────────┬───────────────┘    │
#                                     │                    │
#                                     ▼                    │
#                     ┌───────────────────────────────┐    │
#                     │ Recharge Battery              │    │
#                     │ Battery = 100%                │    │
#                     └───────────────┬───────────────┘    │
#                                     │                    │
#                                     └──────────┬─────────┘
#                                                │
#                                                ▼
#                     ┌───────────────────────────────────┐
#                     │ Get Current Area Status           │
#                     │ status = get_status(location)     │
#                     └─────────────────┬─────────────────┘
#                                       │
#                                       ▼
#                               ┌───────────────────┐
#                               │ Is Area Dirty?    │
#                               │   status == 1     │
#                               └───────┬─────┬─────┘
#                                       │Yes  │No
#                                       │     │
#                                       ▼     ▼
#                     ┌─────────────────────┐   ┌─────────────────────┐
#                     │ Display:            │   │ Display:            │
#                     │ "Area is Dirty"     │   │ "Area is Clean"     │
#                     └──────────┬──────────┘   └──────────┬──────────┘
#                                │                         │
#                                ▼                         ▼
#                     ┌─────────────────────┐   ┌─────────────────────┐
#                     │ Clean Current Area  │   │ No Cleaning Action  │
#                     │ status = 0          │   │ Required            │
#                     └──────────┬──────────┘   └──────────┬──────────┘
#                                │                         │
#                                ▼                         │
#                     ┌─────────────────────┐              │
#                     │ Update Score        │              │
#                     │ Score = Score + 1   │              │
#                     └──────────┬──────────┘              │
#                                │                         │
#                                ▼                         │
#                     ┌─────────────────────┐              │
#                     │ Reduce Battery      │              │
#                     │ Battery =           │              │
#                     │ Battery - 2         │              │
#                     └──────────┬──────────┘              │
#                                │                         │
#                                ▼                         │
#                     ┌─────────────────────┐              │
#                     │ Cleaned Rooms       │              │
#                     │ = Cleaned Rooms + 1 │              │
#                     └──────────┬──────────┘              │
#                                │                         │
#                                └────────────┬────────────┘
#                                             │
#                                             ▼
#                               ┌──────────────────────┐
#                               │ Are More Areas Left? │
#                               └───────┬────────┬─────┘
#                                       │Yes     │No
#                                       │        │
#                                       ▼        ▼
#                     ┌────────────────────────┐  ┌───────────────────────┐
#                     │ Move to Next Area      │  │ Display Final Library │
#                     └───────────┬────────────┘  │ Condition              │
#                                 │               └───────────┬───────────┘
#                                 ▼                           │
#                     ┌────────────────────────┐              ▼
#                     │ Update Performance     │  ┌───────────────────────┐
#                     │ Score = Score - 1      │  │ Display Total Cleaned │
#                     └───────────┬────────────┘  └───────────┬───────────┘
#                                 │                           │
#                                 ▼                           ▼
#                     ┌────────────────────────┐  ┌───────────────────────┐
#                     │ Reduce Battery         │  │ Display Remaining     │
#                     │ Battery = Battery - 1  │  │ Battery               │
#                     └───────────┬────────────┘  └───────────┬───────────┘
#                                 │                           │
#                                 │                           ▼
#                                 │               ┌───────────────────────┐
#                                 │               │ Display Final Score   │
#                                 │               └───────────┬───────────┘
#                                 │                           │
#                                 └───────────┐               │
#                                             │               ▼
#                                             └───────► ┌──────────┐
#                                                       │   STOP   │
#                                                       └──────────┘

# %%
import random




# =========================================================
# ENVIRONMENT CLASS
# Represents the MITAOE college library
# =========================================================

class Environment:

    def __init__(self):

        # 0 = Clean
        # 1 = Dirty

        # The initial condition of every area is random.
        # This makes every run slightly different.
        self.rooms = {
            "Reading Hall": random.randint(0, 1),
            "Book Section": random.randint(0, 1),
            "Reception": random.randint(0, 1),
            "Cabin 1": random.randint(0, 1),
            "Cabin 2": random.randint(0, 1)
        }

    # -----------------------------------------------------
    # Returns the current condition of a particular area
    # -----------------------------------------------------
    def get_status(self, room):
        return self.rooms[room]

    # -----------------------------------------------------
    # Cleans a dirty area
    # -----------------------------------------------------
    def clean_room(self, room):
        self.rooms[room] = 0

    # -----------------------------------------------------
    # Displays the current condition of the library
    # -----------------------------------------------------
    def display(self):

        print("\nCurrent Library Environment:")

        for room, status in self.rooms.items():

            if status == 1:
                print(room, "-> Dirty")
            else:
                print(room, "-> Clean")


# =========================================================
# SIMPLE REFLEX AGENT CLASS
# Represents the automatic vacuum cleaner
# =========================================================

class ReflexAgent:

    def __init__(self, environment):

        # Connect the vacuum cleaner with the environment
        self.environment = environment

        # The vacuum starts from the Reading Hall
        self.location = "Reading Hall"

        # Initial performance score
        self.score = 0

        # Battery starts fully charged
        self.battery = 100

        # Number of areas cleaned by the vacuum
        self.cleaned_rooms = 0

        # Charging station is assumed to be near Reception
        self.charging_station = "Reception"

    # -----------------------------------------------------
    # Charges the vacuum when its battery is low
    # -----------------------------------------------------
    def charge(self):

        print("\nBattery is low!")
        print("Vacuum is going to the charging station...")

        # Move the vacuum to the charging station
        self.location = self.charging_station

        # Restore battery
        self.battery = 100

        print("Battery fully charged: 100%")

    # -----------------------------------------------------
    # Main decision-making method of the reflex agent
    # -----------------------------------------------------
    def act(self):

        # Order in which the vacuum visits the library
        locations = [
            "Reading Hall",
            "Book Section",
            "Reception",
            "Cabin 1",
            "Cabin 2"
        ]

        # Visit each area one by one
        for i in range(len(locations)):

            # Update the current location
            self.location = locations[i]

            print("\n----------------------------------------")
            print("Vacuum is at:", self.location)
            print("Battery:", self.battery, "%")
            print("Score:", self.score)

            # -------------------------------------------------
            # Check battery before performing any action
            # -------------------------------------------------

            if self.battery <= 20:

                self.charge()

            # -------------------------------------------------
            # Check whether the current area is dirty
            # -------------------------------------------------

            status = self.environment.get_status(self.location)

            # If the area is dirty
            if status == 1:

                print("Percept: Area is Dirty")
                print("Action: Cleaning the area...")

                # Clean the area
                self.environment.clean_room(self.location)

                # Cleaning gives a reward
                self.score += 1

                # Cleaning consumes battery
                self.battery -= 2

                # Increase number of cleaned areas
                self.cleaned_rooms += 1

                print("Area cleaned successfully.")

            # If the area is already clean
            else:

                print("Percept: Area is Clean")
                print("Action: No cleaning required.")

            # -------------------------------------------------
            # Move to the next area
            # -------------------------------------------------

            if i < len(locations) - 1:

                print("Moving to the next area...")

                # Movement has a cost
                self.score -= 1

                # Movement consumes battery

                self.battery -= 1

        # FINAL RESULT

        print("\n========================================")
        print("       CLEANING COMPLETED")
        print("========================================")

        print("\nFinal Library Condition:")
        self.environment.display()

        print("\n---------- Agent Performance ----------")
        print("Areas cleaned:", self.cleaned_rooms)
        print("Remaining battery:", self.battery, "%")
        print("Final performance score:", self.score)



# MAIN PROGRAM

# Create the library environment
environment = Environment()

# Show the initial condition of the library
print("========================================")
print("      MITAOE LIBRARY ENVIRONMENT")
print("========================================")

environment.display()

# Create the vacuum cleaner agent
agent = ReflexAgent(environment)

# Start the vacuum cleaner
print("\n========================================")
print("        VACUUM AGENT STARTS")
print("========================================")

agent.act()
# Out:
# ...
#       MITAOE LIBRARY ENVIRONMENT
# ...
#
# Current Library Environment:
# Reading Hall -> Clean
# Book Section -> Clean
# Reception -> Clean
# Cabin 1 -> Clean
# Cabin 2 -> Dirty
#
# ...
#         VACUUM AGENT STARTS
# ...
#
# ----------------------------------------
# Vacuum is at: Reading Hall
# Battery: 100 %
# Score: 0
# Percept: Area is Clean
# Action: No cleaning required.
# Moving to the next area...
#
# ----------------------------------------
# Vacuum is at: Book Section
# Battery: 99 %
# Score: -1
# Percept: Area is Clean
# Action: No cleaning required.
# Moving to the next area...
#
# ----------------------------------------
# Vacuum is at: Reception
# Battery: 98 %
# Score: -2
# Percept: Area is Clean
# Action: No cleaning required.
# Moving to the next area...
#
# ----------------------------------------
# Vacuum is at: Cabin 1
# Battery: 97 %
# Score: -3
# Percept: Area is Clean
# Action: No cleaning required.
# Moving to the next area...
#
# ----------------------------------------
# ...

# %% [markdown]
# # Result
#
# The Smart Autonomous Vacuum Cleaning Agent for the MITAOE Library was successfully implemented using Python.
#
# The agent was able to:
#
# - Detect whether a library area was **Clean (0)** or **Dirty (1)**.
# - Clean the area when it was found to be dirty.
# - Move through different areas of the library, including the Reading Hall, Book Section, Reception, Cabin 1, and Cabin 2.
# - Maintain a performance score based on cleaning and movement actions.
# - Monitor its battery level during operation.
# - Recharge the battery when the battery level became low.
# - Display the final condition of all library areas after completing the cleaning process.
#
# The final performance score may vary because the initial condition of each area is generated randomly. The score depends on the number of dirty areas cleaned and the movement cost incurred by the agent.
#
# Thus, the experiment successfully demonstrated the working of a **Simple Reflex Agent** in a simulated college library environment.
#
# ---
#
# # Conclusion
#
# The Smart Autonomous Vacuum Cleaning Agent for the MITAOE Library was successfully designed and implemented using Python.
#
# The experiment demonstrates the concept of a **Simple Reflex Agent**, where the agent observes the current condition of the environment and performs an action based on predefined condition-action rules.
#
# The agent follows the basic rules:
#
# - If the area is **Dirty**, the agent cleans it.
# - If the area is **Clean**, no cleaning action is performed.
# - If more areas remain, the agent moves to the next area.
# - If the battery level is low, the agent moves to the charging station and recharges.
#
# The traditional vacuum cleaner problem was extended by using multiple areas of the MITAOE Library, random cleanliness conditions, battery monitoring, charging functionality, and a performance scoring system.
#
# Therefore, this experiment provides a practical understanding of how an AI agent can **perceive its environment, make decisions based on current conditions, perform appropriate actions, and evaluate its performance**.
